# %%
import geopandas as gpd
import pandas as pd
import os

# %%
prediction_df = pd.read_parquet('predictedv2.parquet') #Last dataset with predicted type of building
settlements_gdf = gpd.read_file('/home/julian/notebooks/informal_settlement/Patan_neuralNetwork_50_infromal_detection.geojson')

# %%
settlements_gdf.head(4) #check that geometry is using 4326
# Out:
#      confidence   class     fill   stroke  \
# 0  1.805664e-35  formal  #1591EA  #1591EA
# 1  1.805664e-35  formal  #1591EA  #1591EA
# 2  1.736558e-33  formal  #1591EA  #1591EA
# 3  2.053406e-33  formal  #1591EA  #1591EA
#
#                                             geometry
# 0  POLYGON ((72.09932 23.84513, 72.09932 23.84558...
# 1  POLYGON ((72.09932 23.84558, 72.09932 23.84603...
# 2  POLYGON ((72.09932 23.84603, 72.09932 23.84648...
# 3  POLYGON ((72.09932 23.84648, 72.09932 23.84693...

# %%
settlements_gdf[settlements_gdf['class']=='informal'].plot()
settlements_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
prediction_gdf = gpd.GeoDataFrame(
    prediction_df,
    geometry=gpd.GeoSeries.from_wkb(prediction_df['geometry'])
)
prediction_gdf.crs = "EPSG:3857" 
prediction_gdf_new = prediction_gdf.to_crs(4326)

# %%
prediction_gdf_new.head(5) #check that geometry is 4326
# Out:
#    perimeter_in_meters  building_faces bf_source  confidence  \
# 0             6.792135               4    google      0.7125
# 1             7.049124               4    google      0.7023
# 2             7.174945               4    google      0.7471
# 3             6.644836               4    google      0.7436
# 4             9.410371               4    google      0.7229
#
#                                             geometry  longitude   latitude  \
# 0  POLYGON ((72.11827 23.84418, 72.11827 23.8442,...  72.118268  23.844193
# 1  POLYGON ((72.1599 23.78105, 72.1599 23.78106, ...  72.159891  23.781054
# 2  POLYGON ((72.30144 23.72476, 72.30144 23.72479...  72.301436  23.724774
# 3  POLYGON ((72.11305 23.85472, 72.11305 23.85473...  72.113039  23.854728
# 4  POLYGON ((72.15248 23.99026, 72.15247 23.99027...  72.152455  23.990262
#
#                                      id  area_in_meters  height_mean  ...  \
# 0   72.1182684438068:23.844192643954727        0.000128     4.375000  ...
# 1  72.15989074332529:23.781054282336356        0.000129     1.000000  ...
# 2   72.3014359748827:23.724773511447513        0.000130     1.166667  ...
# 3  72.11303936539872:23.854727682982553        0.000130     2.500000  ...
# 4  72.15245506324504:23.990262297534827        0.000133     4.500000  ...
#
#    distance_to_2  nearest_road_type_3  distance_to_3  nearest_road_type_4  \
# 0       0.305624             tertiary       0.246273         unclassified
# 1       0.075187             tertiary       0.077613          residential
# 2       1.000000             tertiary       0.075243          residential
# 3       0.032321             tertiary       0.146824         unclassified
# 4       0.879174             tertiary       0.024405          residential
#
#    distance_to_4 road_density_for_4_fixed road_density_for_5_fixed       SQN  \
# 0       0.061893                 0.012106                 0.000000  0.943885
# 1       0.012951                 0.227083                 0.153201  0.911385
# 2       0.013182                 0.147657                 0.143574  0.898298
# 3       0.033111                 0.122036                 0.027334  0.970864
# 4       0.016939                 0.156636                 0.149722  0.691990
#
#    faces   prediction
# 0      4  Residential
# 1      4  Residential
# 2      4  Residential
# 3      4  Residential
# 4      4  Residential
#
# [5 rows x 43 columns]

# %%
columns_to_add = ['confidence', 'class', 'geometry']
settlements_subset = settlements_gdf[columns_to_add]

# %%
merged_gdf = gpd.sjoin(prediction_gdf_new, settlements_subset, how="left", predicate="intersects")

# %%
merged_gdf = merged_gdf.drop(columns=['index_right'])

# %%
merged_gdf.rename(columns={
    'confidence_right': 'confidence_settlement_clasification',
    'class': 'settlement_clasification'
}, inplace=True)

# %%
merged_gdf[merged_gdf['settlement_clasification']=='informal'].plot()
# Out:
# <Axes: >

# %%
len(merged_gdf)
# Out:
# 202237

# %%
gdf_no_duplicates = merged_gdf.drop_duplicates(subset='geometry', keep='first')

# %%
len(gdf_no_duplicates)
# Out:
# 182313

# %%
gdf_no_duplicates.to_parquet('merged_datasets.parquet')
