# %%
import pandas as pd
import fastparquet

# %%
# for use to combine formal and informal files - results from 1.1 
df1 = pd.read_csv("/area1_formal_cut_50m.json_buildings.csv")
df2 = pd.read_csv("/area2_formal_cut_50m.json_buildings.csv")
frames = [df1, df2]
result = pd.concat(frames)
result.to_parquet('enhanced_formal.parquet', engine='fastparquet')

# %%
# Out:
#    Unnamed: 0.1  Unnamed: 0                                    id   class  \
# 0             0           0   73.00384283778071:19.06891374093071  formal
# 1             1           1  73.00384283778071:19.069364950930712  formal
# 2             2           2  73.00384283778071:19.069816160930714  formal
# 3             3           3  73.00384283778071:19.070267370930715  formal
# 4             4           4  73.00384283778071:19.070718580930716  formal
#
#                                             geometry  \
# 0  {"type": "Feature", "geometry": {"type": "Poly...
# 1  {"type": "Feature", "geometry": {"type": "Poly...
# 2  {"type": "Feature", "geometry": {"type": "Poly...
# 3  {"type": "Feature", "geometry": {"type": "Poly...
# 4  {"type": "Feature", "geometry": {"type": "Poly...
#
#                                              polygon  count     avg_area  \
# 0  POLYGON ((73.00429420678071 19.06891374093071,...      4   344.715500
# ...
